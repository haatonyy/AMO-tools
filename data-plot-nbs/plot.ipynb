# %%
import matplotlib.pyplot as plt
import numpy as np
from utils import load_data, load_params
from science import get_852_RabiFreq_MHz, get_3491_RabiFreq_MHZ, laser_current_to_freq_MHz
from scipy.stats import linregress

# %%
parent = "04092026/04092026-125631-spec-background/"
bgfile1 = parent + "data_01.csv"
bgfile2 = parent + "data_02.csv"
bgfile3 = parent + "data_03.csv"
bgfile4 = parent + "data_04.csv"

xbg1, ybg1 = load_data(bgfile1)
a1, b1, _,_,_= linregress(xbg1,ybg1)
xbg2, ybg2 = load_data(bgfile2)
a2, b2, _,_,_= linregress(xbg2,ybg2)
xbg3, ybg3 = load_data(bgfile3)
a3, b3, _,_,_= linregress(xbg3,ybg3)
xbg4, ybg4 = load_data(bgfile4)
a4, b4, _,_,_= linregress(xbg4,ybg4)

# %%
parent = "04082026/04082026-213004-spec/"
parent2 = "04082026/04082026-234414-spec/"
datafile1 = parent + "data_01.csv"
datafile2 = parent + "data_02.csv"
datafile3 = parent + "data_03.csv"
datafile4 = parent2 + "data_01.csv"
#paramsfile = parent + "params.json"

x1, y1 = load_data(datafile1)
x2, y2 = load_data(datafile2)
x3, y3 = load_data(datafile3)
x4, y4 = load_data(datafile4)

y1 /= (a1 * x1 + b1)
x1 = laser_current_to_freq_MHz(x1, 73)

y2 /= (a2 * x2 + b2)
x2 = laser_current_to_freq_MHz(x2, 73)

y3 /= (a3 * x3 + b3)
x3 = laser_current_to_freq_MHz(x3, 73)

y4 /= (a4 * x4 + b4)
x4 = laser_current_to_freq_MHz(x4, 73)


params = load_params(paramsfile)


#Omega1 = get_3491_RabiFreq_MHZ()
Omega852 = get_852_RabiFreq_MHz(23.7e-3)
Omega1=251

plt.plot(x1[30:-70], y1[30:-70],".-", label=r"$\Omega_{3491}$= 251 MHz")
plt.plot(x2[30:-70], y2[30:-70], ".-" , label=r"$\Omega_{3491}$= 179 MHz")
plt.plot(x3[30:-70], y3[30:-70], ".-",label=r"$\Omega_{3491}$= 80 MHz")
plt.plot(x4[30:-70], y4[30:-70], ".-",label=r"$\Omega_{3491}$= 52 MHz")
plt.xlabel("MHz")
plt.ylabel("(Signal/Background)")
plt.title(r"6S1/2(F=4)→6P3/2→6D5/2, $\Omega_{852}$= " + f"{Omega852:.1f} MHz")
plt.legend()
plt.show()

# %%
parent = "04092026/04092026-121650-spec/"
datafile1 = parent + "data_01.csv"
datafile2 = parent + "data_02.csv"
datafile3 = parent + "data_03.csv"
datafile4 = parent + "data_04.csv"
#paramsfile = parent + "params.json"

x1, y1 = load_data(datafile1)
x2, y2 = load_data(datafile2)
x3, y3 = load_data(datafile3)
x4, y4 = load_data(datafile4)

y1 /= (a1 * x1 + b1)
x1 = laser_current_to_freq_MHz(x1, 73)

y2 /= (a2 * x2 + b2)
x2 = laser_current_to_freq_MHz(x2, 73)

y3 /= (a3 * x3 + b3)
x3 = laser_current_to_freq_MHz(x3, 73)

y4 /= (a4 * x4 + b4)
x4 = laser_current_to_freq_MHz(x4, 73)
#params = load_params(paramsfile)


#Omega1 = get_3491_RabiFreq_MHZ()
Omega852 = get_852_RabiFreq_MHz(1.17e-3)
Omega1=251

plt.plot(x1[30:-70], y1[30:-70],".-", label=r"$\Omega_{3491}$= 251 MHz")
plt.plot(x2[30:-70], y2[30:-70], ".-" , label=r"$\Omega_{3491}$= 179 MHz")
#plt.plot(x3[30:-70], y3[30:-70], ".-",label=r"$\Omega_{3491}$= 80 MHz")
plt.plot(x4[30:-70], y4[30:-70], ".-",label=r"$\Omega_{3491}$= 52 MHz")
plt.xlabel("MHz")
plt.ylabel("(Signal/Background)")
plt.title(r"6S1/2(F=4)→6P3/2→6D5/2, $\Omega_{852}$= " + f"{Omega852:.1f} MHz")
plt.legend()
plt.show()

# %%
parent = "04092026/04092026-150238-spec/"
datafile1 = parent + "data_01.csv"
datafile2 = parent + "data_02.csv"
datafile3 = parent + "data_03.csv"
datafile4 = parent + "data_04.csv"
#paramsfile = parent + "params.json"

x1, y1 = load_data(datafile1)
x2, y2 = load_data(datafile2)
x3, y3 = load_data(datafile3)
x4, y4 = load_data(datafile4)

y1 /= (a1 * x1 + b1)
x1 = laser_current_to_freq_MHz(x1, 73)

y2 /= (a2 * x2 + b2)
x2 = laser_current_to_freq_MHz(x2, 73)

y3 /= (a3 * x3 + b3)
x3 = laser_current_to_freq_MHz(x3, 73)

y4 /= (a4 * x4 + b4)
x4 = laser_current_to_freq_MHz(x4, 73)
#params = load_params(paramsfile)


#Omega1 = get_3491_RabiFreq_MHZ()
Omega852 = get_852_RabiFreq_MHz(23.7e-3)
Omega1=251

plt.plot(x1[:-70], y1[:-70],".-", label=r"$\Omega_{3491}$= 251 MHz")
plt.plot(x2[:-70], y2[:-70], ".-" , label=r"$\Omega_{3491}$= 179 MHz")
plt.plot(x3[:-70], y3[:-70], ".-",label=r"$\Omega_{3491}$= 80 MHz")
plt.plot(x4[:-70], y4[:-70], ".-",label=r"$\Omega_{3491}$= 52 MHz")
plt.xlabel("MHz")
plt.ylabel("(Signal/Background)")
plt.title(r"6S1/2(F=4)→6P3/2→6D5/2, $\Omega_{852}$= " + f"{Omega852:.1f} MHz")
plt.legend()
plt.show()

# %%
parent = "04092026/04092026-170032-spec/"
datafile1 = parent + "data_01.csv"
datafile2 = parent + "data_02.csv"
datafile3 = parent + "data_03.csv"
datafile4 = parent + "data_04.csv"
#paramsfile = parent + "params.json"

x1, y1 = load_data(datafile1)
x2, y2 = load_data(datafile2)
x3, y3 = load_data(datafile3)
x4, y4 = load_data(datafile4)

y1 /= (a1 * x1 + b1)
x1 = laser_current_to_freq_MHz(x1, 73)

y2 /= (a2 * x2 + b2)
x2 = laser_current_to_freq_MHz(x2, 73)

y3 /= (a3 * x3 + b3)
x3 = laser_current_to_freq_MHz(x3, 73)

y4 /= (a4 * x4 + b4)
x4 = laser_current_to_freq_MHz(x4, 73)

#Omega1 = get_3491_RabiFreq_MHZ()
Omega852 = get_852_RabiFreq_MHz(11e-3)
Omega1=251

plt.plot(x1[:-70], y1[:-70],".-", label=r"$\Omega_{3491}$= 251 MHz")
plt.plot(x2[:-70], y2[:-70], ".-" , label=r"$\Omega_{3491}$= 179 MHz")
plt.plot(x3[:-70], y3[:-70], ".-",label=r"$\Omega_{3491}$= 80 MHz")
#plt.plot(x4[:-70], y4[:-70], ".-",label=r"$\Omega_{3491}$= 52 MHz")
plt.xlabel("MHz")
plt.ylabel("(Signal/Background)")
plt.title(r"6S1/2(F=4)→6P3/2→6D5/2, $\Omega_{852}$= " + f"{Omega852:.1f} MHz")
plt.legend()
plt.show()

# %%
parent = "04102026/04102026-001051-spec/"
datafile1 = parent + "data_01.csv"
datafile2 = parent + "data_02.csv"
datafile3 = parent + "data_03.csv"
datafile4 = parent + "data_04.csv"
#paramsfile = parent + "params.json"

x1, y1 = load_data(datafile1)
x2, y2 = load_data(datafile2)
x3, y3 = load_data(datafile3)
x4, y4 = load_data(datafile4)

y1 /= (a1 * x1 + b1)
x1 = laser_current_to_freq_MHz(x1, 73)

y2 /= (a2 * x2 + b2)
x2 = laser_current_to_freq_MHz(x2, 73)

y3 /= (a3 * x3 + b3)
x3 = laser_current_to_freq_MHz(x3, 73)

y4 /= (a4 * x4 + b4)
x4 = laser_current_to_freq_MHz(x4, 73)

#Omega1 = get_3491_RabiFreq_MHZ()
Omega852 = get_852_RabiFreq_MHz(11e-3)
Omega1=251

plt.plot(x1[:-70], y1[:-70],".-", label=r"$\Omega_{3491}$= 251 MHz")
plt.plot(x2[:-70], y2[:-70], ".-" , label=r"$\Omega_{3491}$= 179 MHz")
plt.plot(x3[:-70], y3[:-70], ".-",label=r"$\Omega_{3491}$= 80 MHz")
#plt.plot(x4[:-70], y4[:-70], ".-",label=r"$\Omega_{3491}$= 52 MHz")
plt.xlabel("MHz")
plt.ylabel("(Signal/Background)")
plt.title(r"6S1/2(F=4)→6P3/2→6D5/2, $\Omega_{852}$= " + f"{Omega852:.1f} MHz")
plt.legend()
plt.show()

# %%
f1 = "04102026/04102026-001051-spec/data_01.csv"
x1, y1 = load_data(f1)
x1 = laser_current_to_freq_MHz(x1)

f2 = "04102026/04102026-005437-spec/data_01.csv"
x2, y2 = load_data(f2)
x2 = laser_current_to_freq_MHz(x2)


f3 = "04102026/04102026-005437-spec/data_02.csv"
x3, y3 = load_data(f3)
x3 = laser_current_to_freq_MHz(x3)

f4 = "04102026/04102026-005437-spec/data_03.csv"
x4, y4 = load_data(f4)
x4 = laser_current_to_freq_MHz(x4)


f0 =  "04092026/04092026-170032-spec/data_01.csv"
x0, y0 = load_data(f0)
x0 = laser_current_to_freq_MHz(x0)

plt.plot(x1, y1, ".-", label = "no heat-up 1")
plt.plot(x2, y2, ".-", label = "no heat-up 2")
plt.plot(x3, y3, ".-", label = "no heat-up 3")
plt.plot(x0, y0, ".-", label = "with heat")
plt.xlabel("MHz")
plt.ylabel("(Signal/Background)")
plt.legend()

# %%
parent = "04112026/04112026-001548-spec/"
datafile1 = parent + "data_01.csv"
datafile2 = parent + "data_02.csv"
datafile3 = parent + "data_03.csv"
datafile4 = parent + "data_04.csv"
#paramsfile = parent + "params.json"

x1, y1 = load_data(datafile1)
x2, y2 = load_data(datafile2)
x3, y3 = load_data(datafile3)
x4, y4 = load_data(datafile4)

y1 /= (0.775)
x1 = laser_current_to_freq_MHz(x1, 73)

y2 /= (0.522)
x2 = laser_current_to_freq_MHz(x2, 73)

y3 /= (0.168)
x3 = laser_current_to_freq_MHz(x3, 73)

y4 /= (0.084)
x4 = laser_current_to_freq_MHz(x4, 73)
#params = load_params(paramsfile)


#Omega1 = get_3491_RabiFreq_MHZ()
Omega852 = get_852_RabiFreq_MHz(11e-3)
Omega1=251

plt.plot(x1[:-70], y1[:-70],".-", label=r"$\Omega_{3491}$= 251 MHz")
plt.plot(x2[:-70], y2[:-70], ".-" , label=r"$\Omega_{3491}$= 179 MHz")
plt.plot(x3[:-70], y3[:-70], ".-",label=r"$\Omega_{3491}$= 80 MHz")
plt.plot(x4[:-70], y4[:-70], ".-",label=r"$\Omega_{3491}$= 52 MHz")
plt.xlabel("MHz")
plt.ylabel("(Signal/Background)")
plt.title(r"6S1/2(F=4)→6P3/2→6D5/2, $\Omega_{852}$= " + f"{Omega852:.1f} MHz")
plt.legend()
plt.show()

# %%
parent = "04112026/04112026-004458-spec/"
datafile1 = parent + "data_01.csv"
parent = "04112026/04112026-025902-spec/"
datafile2 = parent + "data_01.csv"

x1, y1 = load_data(datafile1)
x2, y2 = load_data(datafile2)

x1 = laser_current_to_freq_MHz(x1, 73)
x2 = laser_current_to_freq_MHz(x2, 73)

plt.plot(x1, y1)
plt.plot(x2, y2)
plt.xlabel(r"$\Delta_{3491}$ (MHz)")
plt.ylabel("Signal")
plt.title(r"6S1/2(F=4)→6P3/2→6D5/2, $\Omega_{852}$= " + f"{Omega852:.1f} MHz")
plt.show()
