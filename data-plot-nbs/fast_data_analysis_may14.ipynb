# %%
import numpy as np
import matplotlib.pyplot as plt
from exp.data_analysis import load_data, load_param, fit_linear_background_iterative
from exp.science import laser_current_to_freq_MHz_2
from glob import glob
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 3
#       1 import numpy as np
#       2 import matplotlib.pyplot as plt
# ----> 3 from exp.data_analysis import load_data, load_param, fit_linear_background_iterative
#       4 from exp.science import laser_current_to_freq_MHz_2
#       5 from glob import glob
#
# File ~/Documents/AMO-tools/exp/data_analysis.py:4
#       2 import numpy as np
#       3 import json
# ----> 4 from science import laser_current_to_freq_MHz_2
#       6 def fit_linear_background_iterative(x, y, niter=2, sigma=2.5):
#       7     mask = np.ones_like(y, dtype=bool)
#
# ModuleNotFoundError: No module named 'science'
