# %%
import numpy as np

ch1 = np.array([
    1.5622, 1.79259, 1.99483, 2.16364, 2.29064, 2.37101, 2.40117, 2.37986,
    2.30771, 2.18893, 2.02745, 1.83085, 1.60588, 1.36477, 1.1148, 0.86844,
    0.63572, 0.42734, 0.25309, 0.12071, 0.03574, 0.00245, 0.02225, 0.09422,
    0.21487, 0.37857, 0.57768, 0.80339, 1.04516, 1.29198
])

#temp: 47C
ch3 = np.array([
    0.15234, 0.17663, 0.1987, 0.21759, 0.23122, 0.24035, 0.24306, 0.24091,
    0.23348, 0.22072, 0.20345, 0.18241, 0.15825, 0.13225, 0.10562, 0.07946,
    0.05492, 0.03318, 0.01473, 0.00092, -0.00794, -0.01139, -0.00928, -0.00171,
    0.011, 0.0283, 0.04946, 0.07347, 0.09927, 0.12552
])

#temp:58
ch3 = np.array([
    0.14475, 0.1673, 0.18843, 0.2066, 0.21894, 0.22814, 0.23092, 0.22878,
    0.22164, 0.20934, 0.19322, 0.17329, 0.14952, 0.12502, 0.09988, 0.07519,
    0.05161, 0.03087, 0.01348, 0.00038, -0.00803, -0.0113, -0.00929, -0.00208,
    0.01003, 0.02644, 0.04655, 0.06916, 0.09359, 0.1188
])

ch1_min = min(ch1)
ch3_min = min(ch3)

(ch1-ch1_min)/(ch3-ch3_min)
# Out:
# /tmp/ipykernel_3883157/2128148278.py:29: RuntimeWarning: invalid value encountered in divide
#   (ch1-ch1_min)/(ch3-ch3_min)
# array([ 9.99519385, 10.02318029,  9.97536675,  9.91826526,  9.93828179,
#         9.89208152,  9.90306333,  9.90257414,  9.89636816,  9.90971719,
#         9.90123215,  9.9051953 ,  9.97033951,  9.9935446 , 10.00494693,
#        10.01260261, 10.06628517, 10.07564619, 10.11460856, 10.125     ,
#        10.18042813,         nan,  9.85074627,  9.95336226,  9.95874355,
#         9.96608373,  9.9434745 ,  9.95451156,  9.94098579,  9.91183705])

# %%
0.110 * 10 * 1.32 * 0.6
# Out:
# 0.8712000000000001

# %%
0.110/(0.975**4*0.6)*1.32
# Out:
# 0.2677915710839395

# %%
0.975**4 * 0.365 *1/3
# Out:
# 0.10994869335937497

# %%
1/9
# Out:
# 0.1111111111111111

# %%
1/3 * 0.87
# Out:
# 0.29
