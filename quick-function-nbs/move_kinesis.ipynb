# %%
from pathlib import Path
import sys
PROJECT_ROOT = Path.cwd().parent
sys.path.insert(0,str(PROJECT_ROOT))


from exp.connections import check_kinesis_connection
from exp.devices.config import KINESIS_PORT
from exp.devices.k10cr1 import K10CR1

# %%
stage = K10CR1(port="/dev/ttyUSB2")
stage.print_full_settings()
# Out:
# [K10CR1] Connected on /dev/ttyUSB2
# [K10CR1] Scale (pos, vel, accel): (136533, 7329091.44, 1502.0239997136)
# [K10CR1] Scale units: user_step
# [K10CR1:/dev/ttyUSB2] Status: ['enabled']
# {'velocity_parameters': TVelocityParams(min_velocity=0.0, acceleration=9.993848302598519, max_velocity=9.99943862073032), 'jog_parameters': TJogParams(mode='step', step_size=1.0, min_velocity=0.0, acceleration=4.997257035460961, max_velocity=4.999722584986605, stop_mode='profiled'), 'homing_parameters': THomeParams(home_direction='reverse', limit_switch='reverse', velocity=4.999722584986605, offset_distance=2.6000087890839576), 'gen_move_parameters': TGenMoveParams(backlash_distance=1.0), 'limit_switch_parameters': TLimitSwitchParams(hw_kind_cw='make', hw_kind_ccw='make', hw_swapped=False, sw_position_cw=0.0, sw_position_ccw=0.0, sw_kind='ignore')}

# %%
stage.get_position()
# Out:
# 90.0
